# %%
import pandas as pd

# %%
df = pd.read_csv('./pseudomized_aggregated_ALT.csv')

# %%
df
# Out:
#         Unnamed: 0  school  classname                subject  CorrectAnswers  \
# 0                0     148    1996922  Automatiseren (extra)            21.0
# 1                1     148    1996922                Rekenen           295.0
# 2                2     148    1996922               Spelling           296.0
# 3                3     148    1996922                   Taal           197.0
# 4                4     148    1996922   Woordenschat (extra)            30.0
# ...            ...     ...        ...                    ...             ...
# 110226      110226     141    4346542                    NaN             NaN
# 110227      110227     141    4346542                    NaN             NaN
# 110228      110228     141    4346542                    NaN             NaN
# 110229      110229     141    4346542                    NaN             NaN
# 110230      110230     141    4346542                    NaN             NaN
#
# ...

# %%
school_df = df[(df['school'] == '148')]

# %%
df[(df['subject'] == 'Woordenschat (extra)') & (df['lln.ID.school'] == 3566797)]
# Out:
#        Unnamed: 0  school  classname               subject  CorrectAnswers  \
# 4               4     148    1996922  Woordenschat (extra)            30.0
# 77346       77346     148    3023549  Woordenschat (extra)            28.0
#
#        TotalAnswers  CorrectAdaptive  TotalAdaptiveAnswers  \
# 4              48.0             15.0                  19.0
# 77346          46.0              0.0                   0.0
#
#        TotalAdaptiveExercises  TotalExercises periode.van periode.tot  \
# 4                        15.0            30.0    aug 2014    jan 2015
# 77346                     0.0            28.0    feb 2016    jul 2016
#
#        lln.ID.school          van.tot
# 4            3566797  aug2014|jan2015
# 77346        3566797  feb2016|jul2016

# %%
data = []
for i in school_df['lln.ID.school'].unique():
    classes = school_df[school_df['lln.ID.school'] == i]['classname'].unique()
    data.append({'studentID': i, 'classIDs': classes})

# %%
student_data = pd.DataFrame(data)
student_data.to_csv('studentData.csv', index=False)
school_df.to_csv('schoolData.csv', index=False)

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   studentID  159 non-null    int64
#  1   classIDs   159 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.6+ KB
